# %% [markdown]
# HackerRank problem: <br />
# https://www.hackerrank.com/challenges/staircase/problem
# <img src="http://pythonworkshops.com/img/hackerrank-only-problem.png" />

# %% [markdown]
# <pre>
# Stage 1: [Requirment Analysis]
# i)   Describe the requirement clearly including the stake holders and their actions.
# ii)  Conditions specified and that needs to be followed for solving given problem. (could include deployment environment details)
# iii) Input provided
# iv)  Output expected
# v)   Test Cases
# {Best practices, always get your stage 1 reviewed and approved by customer before going to the next stage.}
#
#
# Stage 2: [Design]
# Break down problem/requirement into parts.
# (basing on stake holders, departments, change in state, location etc)
# [Part 1, Part 2 , Part 3...,Part n]
#
# Stage 3: [Design]
# Take each part from the above breakdown and write an algorithm for each part
# Part 1:
#
# Part 2:
#
# .
# .
# .
# Part n:
#
#
# Linking/Integration code snippets for above parts { if required as per requirement }
#
# Stage 4: [Coding]
# Take each part algorithm and convert into the language in which you would deploy the solution
# {Java, JS, Python, .Net, any language}
#
# Stage 5: [Deployment]
# Test the above solution to see if its providing required solution, you can also prepare set of testcases (from Stage 1) or more and test it, if its not solving/satisfying given problem/requirement. Go to Stage 2 and break it down further or see if you missed any part of the requirement during breakdown.
# Deploy the final solution of the program in the target environment as per requirement and get it test by the customers.
# </pre>

# %%
#Sample Solution below, 

"""

Stage 1: 
Requirement: 
We need to print a staircase with height and base equal to the user input value. we need to use # symbol as building block for stair case. 

Condition: 
the last/bottom line should not have any spaces from the left
the height and the width of the staircase needs to be same. 

Input: 
User will give input n positive integer number of steps. 10, 5, 15

Output: 
Print a staircase of size n using # symbols

testcases: 
Given 4 as user input the output should print 4 stair cases with bottom line having 4 #'s. 


Stage 2:
Part 1: 
Take user input 
Part 2: 
Print the spaces 
Part 3:
Print the # symbols
Part 4: 
Set the end condition

Stage 3: 

Part 1: 
Take user input 
  take n = input from user 
Part 2: 
Print the spaces 
  for x = 1 to n 
	for 1 to n-x n-x > 0
		print space
Part 3:
Print the # symbols
  for x = 1 to n 
	for n-x to n
		print #
Part 4: 
Set the end condition
no of rows == n: stop the program. 

Integration code: 
we can merge both 2 and 3 parts together into one loop
for x = 1 to n 
	for y=1 to n-x n-x > y
		print space
	for z=n-x to n
		print #
Stage 4:  

var n = prompt("Input no of Stairs");
for(var i=1;i<=n;i++) {
	for(var j=1;j<=n-i;j++) {
		document.write(" ");
	}
	for(var k=1;k<=i;k++) {
		document.write("#");
	}
	document.write("<br/>");
}


Stage 5: 
Try to Run above javascript online or using a html page and
see if it will run directly as written. 
http://js.do/





"""
n="Approach for the given problem" #dummy
